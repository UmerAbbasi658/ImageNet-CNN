# %% [markdown]
# LeNet Implementation as it is important and adviced to work when there are hand written digits

# %%
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout,Flatten,Conv2D,MaxPooling2D
from keras import optimizers
from keras.utils import to_categorical,plot_model
import matplotlib.pyplot as plt
from keras.layers import BatchNormalization
import numpy as np
np.random.seed(123)

# %%
# (x_train,y_train),(x_test,y_test)=keras.datasets.mnist.load_data()

# %%
#  x_train=x_train.reshape(x_train.shape[0],28,28,1)
#  x_test=x_test.reshape(x_test.shape[0],28,28,1)

# #  Normalization
# x_train=x_train/255
# x_test=x_test/255

# # One hot Encoding
# y_train=to_categorical(y_train,10)
# y_test=to_categorical(y_test,10)

# %%
# model= Sequential()
# model.add(Conv2D(6,kernel_size=(5,5),input_shape=(28,28,1),activation='tanh'))
# model.add(MaxPooling2D(pool_size=(2,2)))
# model.add(Conv2D(16,kernel_size=(5,5),activation='tanh'))
# model.add(MaxPooling2D(pool_size=(2,2)))
# model.add(Flatten())
# model.add(Dense(120,activation='tanh'))
# model.add(Dense(84,activation='tanh'))
# model.add(Dense(10,activation='softmax'))

# %%
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# H=model.fit(x_train,y_train,validation_split=0.3,epochs=10,batch_size=128,verbose=1)

# %%
# train_loss,train_acc=model.evaluate(x_train,y_train)
# print('Train Accuracy:',train_acc)

# %%
# test_loss,test_acc=model.evaluate(x_test,y_test)
# print('Train Accuracy:',test_acc)

# %%
# h=H.history

# # Plot the training loss and validation loss
# plt.figure(figsize=(10, 6))
# plt.plot(h['loss'], label='Training Loss')
# plt.plot(h['val_loss'], label='Validation Loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.title('Training and Validation Loss Over Epochs')
# plt.legend()
# plt.grid(True)
# plt.show()

# %% [markdown]
# AlexNet Implementation

# %%
# !pip install tflearn tensorflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.3/107.3 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tflearn: filename=tflearn-0.5.0-py3-none-any.whl size=127283 sha256=f9f12627f493a680074c9a54418fcf0c09b6015631974ec5f1a41ab7d590973b
#   Stored in directory: /root/.cache/pip/wheels/55/fb/7b/e06204a0ceefa45443930b9a250cb5ebe31def0e4e8245a465
# Successfully built tflearn
# ...

# %%
# import os
# import urllib.request
# import tarfile

# def download_and_extract_flowers17(dataset_path='17flowers.tgz'):
#     url = 'http://www.robots.ox.ac.uk/~vgg/data/flowers/17/17flowers.tgz'
#     if not os.path.exists(dataset_path):
#         urllib.request.urlretrieve(url, dataset_path)
#         with tarfile.open(dataset_path, 'r:gz') as tar:
#             tar.extractall(path='.')
#     return os.path.join('.', 'jpg')

# # Function to load the dataset
# def load_data(one_hot=True):
#     dataset_path = download_and_extract_flowers17()
#     images, labels = [], []
#     for label in range(17):
#         for i in range(80):
#             image_path = os.path.join(dataset_path, f'image_{label * 80 + i + 1:04d}.jpg')
#             image = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
#             image = tf.keras.preprocessing.image.img_to_array(image)
#             images.append(image)
#             labels.append(label)
#     images = np.array(images)
#     labels = np.array(labels)
#     if one_hot:
#         labels = to_categorical(labels, num_classes=17)
#     return images, labels

# # Load the data
# x, y = load_data(one_hot=True)

# # Split the data into training and testing sets
# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
# model=Sequential()

# model.add(Conv2D(filters=96,kernel_size=(11,11),input_shape=(224,224,3),strides=(4,4),padding='valid',activation='relu'))
# model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2),padding='valid'))
# model.add(BatchNormalization())

# model.add(Conv2D(filters=256,kernel_size=(11,11),padding='valid',activation='relu',strides=(1,1)))
# model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2),padding='valid'))
# model.add((BatchNormalization()))

# model.add(Conv2D(filters=384,kernel_size=(3,3),padding='valid',activation='relu',strides=(1,1)))
# # model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2),padding='valid'))
# model.add((BatchNormalization()))

# model.add(Conv2D(filters=384,kernel_size=(3,3),padding='valid',activation='relu',strides=(1,1)))
# model.add((BatchNormalization()))

# model.add(Conv2D(filters=256,kernel_size=(3,3),padding='valid',activation='relu',strides=(1,1)))
# model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2),padding='valid'))
# model.add((BatchNormalization()))

# model.add(Flatten())
# # Now adding Dense Layers
# model.add(Dense(4096,activation='relu',input_shape=(224,224,3)))
# model.add(Dropout(0.4))
# model.add(BatchNormalization())

# model.add(Dense(4096,activation='relu'))
# model.add(Dropout(0.4))
# model.add(BatchNormalization())

# model.add(Dense(1000,activation='relu'))
# model.add(Dropout(0.4))
# model.add(BatchNormalization())

# model.add(Dense(17,activation='softmax'))
# model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_5 (Conv2D)           (None, 54, 54, 96)        34944
#
#  max_pooling2d_3 (MaxPoolin  (None, 27, 27, 96)        0
#  g2D)
#
#  batch_normalization_8 (Bat  (None, 27, 27, 96)        384
#  chNormalization)
#
#  conv2d_6 (Conv2D)           (None, 17, 17, 256)       2973952
#
#  max_pooling2d_4 (MaxPoolin  (None, 8, 8, 256)         0
#  g2D)
#
#  batch_normalization_9 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 6, 6, 384)         885120
#
#  batch_normalization_10 (Ba  (None, 6, 6, 384)         1536
#  tchNormalization)
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 384)         1327488
#
#  batch_normalization_11 (Ba  (None, 4, 4, 384)         1536
#  tchNormalization)
#
#  conv2d_9 (Conv2D)           (None, 2, 2, 256)         884992
#
# ...

# %%
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# H=model.fit(x_train,y_train,epochs=5,validation_split=0.3,batch_size=128,verbose=1)
# Out:
# Epoch 1/5
# 6/6 [==============================] - 128s 21s/step - loss: 2.8816 - accuracy: 0.3198 - val_loss: 1032.0776 - val_accuracy: 0.1329
# Epoch 2/5
# 6/6 [==============================] - 113s 19s/step - loss: 2.2898 - accuracy: 0.3438 - val_loss: 1374.5350 - val_accuracy: 0.1049
# Epoch 3/5
# 6/6 [==============================] - 134s 22s/step - loss: 1.8758 - accuracy: 0.3934 - val_loss: 628.7310 - val_accuracy: 0.1119
# Epoch 4/5
# 6/6 [==============================] - 124s 21s/step - loss: 1.7000 - accuracy: 0.4595 - val_loss: 260.0748 - val_accuracy: 0.1084
# Epoch 5/5
# 6/6 [==============================] - 124s 21s/step - loss: 1.4254 - accuracy: 0.5330 - val_loss: 169.9787 - val_accuracy: 0.1189

# %% [markdown]
# Visual Geometry Group (VGG)

# %%
# import os
# import urllib.request
# import zipfile

# # Function to download and extract the Cats and Dogs dataset
# def download_and_extract_cats_dogs(dataset_path='cats_and_dogs_filtered.zip', extract_path='cats_and_dogs_filtered'):
#     url = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
#     if not os.path.exists(dataset_path):
#         urllib.request.urlretrieve(url, dataset_path)
#     if not os.path.exists(extract_path):
#         with zipfile.ZipFile(dataset_path, 'r') as zip_ref:
#             zip_ref.extractall(extract_path)
#     return extract_path

# # Function to count total number of images
# def count_images(dataset_path):
#     total_images = 0
#     for root, dirs, files in os.walk(dataset_path):
#         for file in files:
#             if file.endswith(".jpg"):
#                 total_images += 1
#     print(f"Total number of images: {total_images}")
#     return total_images

# # Download and extract the dataset
# dataset_path = download_and_extract_cats_dogs()

# # Count total number of images
# total_images = count_images(os.path.join(dataset_path, 'cats_and_dogs_filtered'))
# Out:
# Total number of images: 3000

# %%
#  from keras.preprocessing.image import ImageDataGenerator
# #  for data augemnetation

# %%
# trdata=ImageDataGenerator()
# trdata=trdata.flow_from_directory(directory='cats_and_dogs_filtered/cats_and_dogs_filtered/train',target_size=(224,224))
# testdata=ImageDataGenerator()
# testdata=testdata.flow_from_directory(directory='cats_and_dogs_filtered/cats_and_dogs_filtered/validation',target_size=(224,224))
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
# model=Sequential()
# model.add(Conv2D(input_shape=(224,224,3),activation='relu',padding='same',kernel_size=(3,3),filters=64))
# model.add(Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'))
# model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

# model.add(Conv2D(input_shape=(224,224,3),activation='relu',padding='same',kernel_size=(3,3),filters=128))
# model.add(Conv2D(filters=128,kernel_size=(3,3),padding='same',activation='relu'))
# model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

# model.add(Conv2D(input_shape=(224,224,3),activation='relu',padding='same',kernel_size=(3,3),filters=128))
# model.add(Conv2D(filters=128,kernel_size=(3,3),padding='same',activation='relu'))
# model.add(Conv2D(filters=256,kernel_size=(3,3),padding='same',activation='relu'))
# model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

# model.add(Conv2D(input_shape=(224,224,3),activation='relu',padding='same',kernel_size=(3,3),filters=512))
# model.add(Conv2D(filters=512,kernel_size=(3,3),padding='same',activation='relu'))
# model.add(Conv2D(filters=512,kernel_size=(3,3),padding='same',activation='relu'))
# model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

# model.add(Conv2D(input_shape=(224,224,3),activation='relu',padding='same',kernel_size=(3,3),filters=512))
# model.add(Conv2D(filters=512,kernel_size=(3,3),padding='same',activation='relu'))
# model.add(Conv2D(filters=512,kernel_size=(3,3),padding='same',activation='relu'))
# model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

# model.add(Flatten())
# model.add(Dense(4096,activation='relu'))
# model.add(Dense(4096,activation='relu'))
# model.add(Dense(2,activation='softmax'))

# model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')
# model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 224, 224, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 64)      0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 128)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 128)       147584
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 128)       147584
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 256)       295168
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 256)       0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 512)       2359808
#
# ...

# %%
# from keras.callbacks import ModelCheckpoint,EarlyStopping
# checkpoints=ModelCheckpoint('vgg16',monitor='val_accuracy',verbose=1,save_best_only=True,save_weights_only=False,mode='auto')
# callbacks=EarlyStopping(monitor='val_accuracy',min_delta=0.1,patience=5,verbose=1,mode='auto')

# H=model.fit_generator(generator=trdata,steps_per_epoch=10,validation_data=testdata,validation_steps=10,epochs=10,callbacks=[checkpoints,callbacks])
# Out:
# <ipython-input-32-eb19bef8d00d>:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   H=model.fit_generator(generator=trdata,steps_per_epoch=10,validation_data=testdata,validation_steps=10,epochs=10,callbacks=[checkpoints,callbacks])
# Epoch 1/10
# 10/10 [==============================] - ETA: 0s - loss: 135.9457 - accuracy: 0.4781
# Epoch 1: val_accuracy improved from -inf to 0.50937, saving model to vgg16
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 852s 87s/step - loss: 135.9457 - accuracy: 0.4781 - val_loss: 0.7749 - val_accuracy: 0.5094
# Epoch 2/10
# 10/10 [==============================] - ETA: 0s - loss: 0.7008 - accuracy: 0.5219
# Epoch 2: val_accuracy did not improve from 0.50937
# ...

# %%
# import matplotlib.pyplot as plt


# from keras.preprocessing import image
# img = image.load_img("/content/A-Cat.jpg",target_size=(224,224))
# img = np.asarray(img)
# plt.imshow(img)
# img = np.expand_dims(img, axis=0)
# from keras.models import load_model
# saved_model = load_model("vgg16")
# output = saved_model.predict(img)
# if output[0][0] > output[0][1]:
#     print("dog")
# else:
#     print('cat')

# %%
# output[0][]
# Out:
# 0.40675208

# %% [markdown]
# Google Net or Inception Net

# %%
from keras.datasets import cifar10
(x_train,y_train),(x_test,y_test)=cifar10.load_data()
# Out:
# ...
# 170498071/170498071 [==============================] - 13s 0us/step

# %%
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')
x_train=x_train/255
x_test=x_test/255

# %%
y_train=to_categorical(y_train,10)
y_train=to_categorical(y_test,10)

# %%
len(y_test)
# Out:
# 10000

# %%
from keras.layers import Input
input_image=Input(shape=(32,32,3))

# %%
from warnings import filters
tower_1=Conv2D(filters=64,kernel_size=(1,1),padding='same',activation='relu')(input_image)
tower_1=Conv2D(64,kernel_size=(3,3),padding='same',activation='relu')(tower_1)

tower_2=Conv2D(64,kernel_size=(1,1),activation='relu',padding='same')(input_image)
tower_2=Conv2D(64,kernel_size=(3,3),padding='same',activation='relu')(tower_2)

tower_3=MaxPooling2D((3,3),strides=(1,1),padding='same')(input_image)
tower_3=Conv2D(64,kernel_size=(1,1),padding='same',activation='relu')(tower_3)

output=keras.layers.concatenate([tower_1,tower_2,tower_3])
output=Flatten()(output)
final=Dense(10,activation='softmax')(output)

# %%
from keras.models import Model
model=Model(inputs=input_image,outputs=final)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_2 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 64)           256       ['input_2[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 32, 32, 64)           256       ['input_2[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 32, 32, 3)            0         ['input_2[0][0]']
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 64)           36928     ['conv2d_18[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 32, 32, 64)           36928     ['conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 32, 32, 64)           256       ['max_pooling2d_6[0][0]']
#
#  concatenate_1 (Concatenate  (None, 32, 32, 192)          0         ['conv2d_19[0][0]',
# ...

# %%
# Define optimizer with initial learning rate and momentum
epochs = 5
lrate = 0.01
sgd = SGD(learning_rate=lrate, momentum=0.9, nesterov=False)

# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)

# Define a learning rate scheduler
def lr_schedule(epoch):
    return lrate * (0.1 ** (epoch // 10))

# Create a LearningRateScheduler callback
lr_scheduler = LearningRateScheduler(lr_schedule)

# Train the model
model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=epochs, batch_size=32, callbacks=[lr_scheduler])
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.8104 - accuracy: 0.7156 - val_loss: 0.9400 - val_accuracy: 0.6771 - lr: 0.0100
# Epoch 2/5
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7532 - accuracy: 0.7345 - val_loss: 0.9926 - val_accuracy: 0.6692 - lr: 0.0100
# Epoch 3/5
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6985 - accuracy: 0.7547 - val_loss: 1.0009 - val_accuracy: 0.6735 - lr: 0.0100
# Epoch 4/5
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6497 - accuracy: 0.7714 - val_loss: 1.0054 - val_accuracy: 0.6754 - lr: 0.0100
# Epoch 5/5
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.6133 - accuracy: 0.7821 - val_loss: 1.0088 - val_accuracy: 0.6734 - lr: 0.0100

# %%
train_loss,train_acc=model.evaluate(x_train,y_train)
print('Train Accuracy',train_acc)
# Out:
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.4890 - accuracy: 0.8298
# Train Accuracy 0.8298400044441223

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print('Test Accuracy',test_acc)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.0088 - accuracy: 0.6734
# Test Accuracy 0.6733999848365784
